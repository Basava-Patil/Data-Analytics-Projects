# %% [markdown]
# ## Telecom and Streaming Services

# %%
# step:-1 Import  necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data loading

# %%
Subscribers_df = pd.read_csv("E:\python\Myproject\subscribers.csv",index_col = "Unnamed: 0")
Content_df = pd.read_csv("E:\python\Myproject\content.csv", index_col = "Unnamed: 0")
Content_consumption_df = pd.read_csv("E:\python\Myproject\content_consumption.csv",index_col = "Unnamed: 0")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13492\1593399953.py:1: SyntaxWarning: invalid escape sequence '\p'
#   Subscribers_df = pd.read_csv("E:\python\Myproject\subscribers.csv",index_col = "Unnamed: 0")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13492\1593399953.py:2: SyntaxWarning: invalid escape sequence '\p'
#   Content_df = pd.read_csv("E:\python\Myproject\content.csv", index_col = "Unnamed: 0")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13492\1593399953.py:3: SyntaxWarning: invalid escape sequence '\p'
#   Content_consumption_df = pd.read_csv("E:\python\Myproject\content_consumption.csv",index_col = "Unnamed: 0")

# %%
Subscribers_df.head()
# Out:
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDJS0000751588f     18-24    Tier 1        2024-06-10           Premium
# 1  UIDJS000093eeb86     18-24    Tier 1        2024-11-09              Free
# 2  UIDJS00010d7fa1e     25-34    Tier 1        2024-08-08              Free
# 3  UIDJS00013411a85     35-44    Tier 2        2024-05-31               VIP
# 4  UIDJS0003a3f54cf     35-44    Tier 1        2024-09-20           Premium
#
#   last_active_date plan_change_date new_subscription_plan
# 0              NaN              NaN                   NaN
# 1              NaN              NaN                   NaN
# 2              NaN              NaN                   NaN
# 3              NaN              NaN                   NaN
# 4              NaN              NaN                   NaN

# %%
Content_df.head()
# Out:
#        content_id content_type language   genre  runtime
# 0  CJSMBEACT2e633        Movie  Bengali  Action       90
# 1  CJSMBEACT34aec        Movie  Bengali  Action      135
# 2  CJSMBEACT83b46        Movie  Bengali  Action      120
# 3  CJSMBECOM12e7a        Movie  Bengali  Comedy      120
# 4  CJSMBECOM5431a        Movie  Bengali  Comedy      135

# %%
Content_consumption_df.head()
# Out:
#             user_id device_type  total_watch_time_mins
# 0  UIDJS877cc0e02c9      Mobile                  14613
# 1  UIDJS06384e7ff06      Mobile                  13271
# 2  UIDJSc3997b7beb7      Mobile                   4644
# 3  UIDJS66726ce2325      Mobile                   5734
# 4  UIDJS040119b6107      Mobile                   2939

# %%
Content_consumption_avg = Content_consumption_df.groupby('device_type').mean('total_watch_time_mins')
Content_consumption_avg = Content_consumption_avg.reset_index()
Content_consumption_avg
# Out:
#   device_type  total_watch_time_mins
# 0      Laptop            4857.260399
# 1      Mobile           10563.645316
# 2          TV            5682.622277

# %%
sns.barplot(data=Content_consumption_avg, x= 'device_type', y= 'total_watch_time_mins')
# Out:
# <Axes: xlabel='device_type', ylabel='total_watch_time_mins'>

# %%
#  get basci statistcs of numerical columns
Subscribers_df.describe()
# Out:
#                  user_id age_group city_tier subscription_date  \
# count              44620     44620     44620             44620
# unique             44620         4         3               335
# top     UIDJS0000751588f     25-34    Tier 1        2024-11-03
# freq                   1     20069     25451               177
#
#        subscription_plan last_active_date plan_change_date  \
# count              44620             6652             7090
# unique                 3              328              335
# top                  VIP       2024-12-01       2024-11-30
# freq               19157               86               43
#
#        new_subscription_plan
# count                   7090
# unique                     3
# top                  Premium
# freq                    3504

# %%
Content_consumption_df.describe()
# Out:
#        total_watch_time_mins
# count          133860.000000
# mean             7034.509331
# std              6342.440494
# min                66.000000
# 25%              2192.000000
# 50%              5154.000000
# 75%             10044.000000
# max             42635.000000

# %%
Content_df.describe()
# Out:
#            runtime
# count  2360.000000
# mean     89.550847
# std      52.637611
# min       5.000000
# 25%      30.000000
# 50%      90.000000
# 75%     120.000000
# max     300.000000

# %%
Subscribers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44620 entries, 0 to 44619
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                44620 non-null  object
#  1   age_group              44620 non-null  object
#  2   city_tier              44620 non-null  object
#  3   subscription_date      44620 non-null  object
#  4   subscription_plan      44620 non-null  object
#  5   last_active_date       6652 non-null   object
#  6   plan_change_date       7090 non-null   object
#  7   new_subscription_plan  7090 non-null   object
# dtypes: object(8)
# memory usage: 3.1+ MB

# %%
# get quick summary of dataset
Content_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2360 entries, 0 to 2359
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   content_id    2360 non-null   object
#  1   content_type  2360 non-null   object
#  2   language      2360 non-null   object
#  3   genre         2360 non-null   object
#  4   runtime       2360 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 110.6+ KB

# %%
# Get quick summary of data set
Content_consumption_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133860 entries, 0 to 133859
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                133860 non-null  object
#  1   device_type            133860 non-null  object
#  2   total_watch_time_mins  133860 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 4.1+ MB

# %%
# check the columns and rows
Subscribers_df.shape
# Out:
# (44620, 8)

# %%
Content_consumption_df.shape
# Out:
# (133860, 3)

# %%
Content_df.shape
# Out:
# (2360, 5)

# %%
#  check the columns name
Content_df.columns
# Out:
# Index(['content_id', 'content_type', 'language', 'genre', 'runtime'], dtype='object')

# %% [markdown]
# ## Date data validtion

# %%
Subscribers_df['subscription_date']= pd.to_datetime(Subscribers_df['subscription_date'])
Subscribers_df['last_active_date'] = pd.to_datetime(Subscribers_df['last_active_date'])
Subscribers_df['plan_change_date'] = pd.to_datetime(Subscribers_df['plan_change_date'])

# %%
Subscribers_df.dtypes
# Out:
# user_id                          object
# age_group                        object
# city_tier                        object
# subscription_date        datetime64[ns]
# subscription_plan                object
# last_active_date         datetime64[ns]
# plan_change_date         datetime64[ns]
# new_subscription_plan            object
# dtype: object

# %%
Subscribers_df.columns
# Out:
# Index(['user_id', 'age_group', 'city_tier', 'subscription_date',
#        'subscription_plan', 'last_active_date', 'plan_change_date',
#        'new_subscription_plan'],
#       dtype='object')

# %%
Subscribers_df.isnull().sum()
# Out:
# user_id                      0
# age_group                    0
# city_tier                    0
# subscription_date            0
# subscription_plan            0
# last_active_date         37968
# plan_change_date         37530
# new_subscription_plan    37530
# dtype: int64

# %% [markdown]
# ## split data to  numerical  and categorical columns

# %%
Content_df
# Out:
#           content_id content_type language     genre  runtime
# 0     CJSMBEACT2e633        Movie  Bengali    Action       90
# 1     CJSMBEACT34aec        Movie  Bengali    Action      135
# 2     CJSMBEACT83b46        Movie  Bengali    Action      120
# 3     CJSMBECOM12e7a        Movie  Bengali    Comedy      120
# 4     CJSMBECOM5431a        Movie  Bengali    Comedy      135
# ...              ...          ...      ...       ...      ...
# 2355  CJSSTETHR767c0       Series   Telugu  Thriller       20
# 2356  CJSSTETHR8b80e       Series   Telugu  Thriller       30
# 2357  CJSSTETHR92817       Series   Telugu  Thriller       45
# 2358  CJSSTETHRccd4d       Series   Telugu  Thriller       30
# 2359  CJSSTETHRdfb63       Series   Telugu  Thriller       45
#
# [2360 rows x 5 columns]

# %%
content_numerical_df=Content_df.select_dtypes(include='int')
content_categorical_df=Content_df.select_dtypes(include='O')

# %%
content_numerical_df.head()
# Out:
#    runtime
# 0       90
# 1      135
# 2      120
# 3      120
# 4      135

# %%
content_categorical_df.head()
# Out:
#        content_id content_type language   genre
# 0  CJSMBEACT2e633        Movie  Bengali  Action
# 1  CJSMBEACT34aec        Movie  Bengali  Action
# 2  CJSMBEACT83b46        Movie  Bengali  Action
# 3  CJSMBECOM12e7a        Movie  Bengali  Comedy
# 4  CJSMBECOM5431a        Movie  Bengali  Comedy

# %% [markdown]
# ## Miss value treatement

# %% [markdown]
# ### Numerical data
#
# ### *mean * median

# %% [markdown]
# ### Categorical  data
# ### *mode

# %% [markdown]
# ### Outlier Detection

# %%
content_numerical_df.describe()
# Out:
#            runtime
# count  2360.000000
# mean     89.550847
# std      52.637611
# min       5.000000
# 25%      30.000000
# 50%      90.000000
# 75%     120.000000
# max     300.000000

# %%
sns.boxplot(content_numerical_df['runtime'],orient='h')
# Out:
# <Axes: xlabel='runtime'>

# %%
# univariate analysis

sns.histplot(content_numerical_df['runtime'],kde=True)
# Out:
# <Axes: xlabel='runtime', ylabel='Count'>

# %%
sns.countplot(content_categorical_df['content_type'])
# Out:
# <Axes: xlabel='count', ylabel='content_type'>

# %%
sns.countplot(content_categorical_df['language'])
# Out:
# <Axes: xlabel='count', ylabel='language'>

# %% [markdown]
# ### Bivariate analysis

# %%
sns.countplot(data=content_categorical_df,  y='language', hue='content_type')
# Out:
# <Axes: xlabel='count', ylabel='language'>

# %% [markdown]
# ### Subscriber Insights: Analyse trends in subscriber acquisition and demographic variations.

# %%
Subscribers_df.head()
# Out:
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDJS0000751588f     18-24    Tier 1        2024-06-10           Premium
# 1  UIDJS000093eeb86     18-24    Tier 1        2024-11-09              Free
# 2  UIDJS00010d7fa1e     25-34    Tier 1        2024-08-08              Free
# 3  UIDJS00013411a85     35-44    Tier 2        2024-05-31               VIP
# 4  UIDJS0003a3f54cf     35-44    Tier 1        2024-09-20           Premium
#
#   last_active_date plan_change_date new_subscription_plan
# 0              NaT              NaT                   NaN
# 1              NaT              NaT                   NaN
# 2              NaT              NaT                   NaN
# 3              NaT              NaT                   NaN
# 4              NaT              NaT                   NaN

# %%
# Fetching subscription_plan count in age_group category
Sub_plan_vs_age = Subscribers_df.groupby('age_group').value_counts(['subscription_plan']).to_frame(). reset_index()
Sub_plan_vs_age
# Out:
#    age_group subscription_plan  count
# 0      18-24               VIP   3252
# 1      18-24           Premium   2305
# 2      18-24              Free   2119
# 3      25-34               VIP   8673
# 4      25-34           Premium   5938
# 5      25-34              Free   5458
# 6      35-44               VIP   4846
# 7      35-44           Premium   3417
# 8      35-44              Free   3011
# 9        45+               VIP   2386
# 10       45+           Premium   1707
# 11       45+              Free   1508

# %%
sns.barplot(data =Sub_plan_vs_age, x = 'age_group', y='count',hue='subscription_plan')
# Out:
# <Axes: xlabel='age_group', ylabel='count'>

# %%
Subscribers_df.head(2)
# Out:
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDJS0000751588f     18-24    Tier 1        2024-06-10           Premium
# 1  UIDJS000093eeb86     18-24    Tier 1        2024-11-09              Free
#
#   last_active_date plan_change_date new_subscription_plan
# 0              NaT              NaT                   NaN
# 1              NaT              NaT                   NaN

# %%
# Fetching subscribers count on daily basis

subscription_data = Subscribers_df.groupby(['subscription_date'])['user_id'].count().to_frame().reset_index()
subscription_data
# Out:
#     subscription_date  user_id
# 0          2024-01-01      116
# 1          2024-01-02      137
# 2          2024-01-03      133
# 3          2024-01-04      135
# 4          2024-01-05      126
# ..                ...      ...
# 330        2024-11-26      145
# 331        2024-11-27      134
# 332        2024-11-28      138
# 333        2024-11-29      156
# 334        2024-11-30      133
#
# [335 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

fig, ax=plt.subplots(figsize=(17,4))
sns.lineplot(data=subscription_data, x ='subscription_date', y='user_id', markers='*')
plt.title('Subscription Trend Over time' )
plt.xlabel('subscription_data')
# plt.ylabel('Number of User')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
# Out:
# Text(0.5, 0, 'subscription_data')

# %%
plan_changed_cus=Subscribers_df[['user_id','plan_change_date','subscription_plan','new_subscription_plan']].dropna()
# subscribers_df[['user_id','plan_change_date','subscription_plan','new_subscription_plan']]
plan_changed_cus.head(10)
# Out:
#              user_id plan_change_date subscription_plan new_subscription_plan
# 12  UIDJS000cd6a7fe8       2024-12-18           Premium                   VIP
# 19  UIDJS0019b04b32f       2024-08-11               VIP                  Free
# 23  UIDJS001defd7e03       2024-08-18               VIP                  Free
# 47  UIDJS003cb5a2cd7       2024-10-05               VIP                  Free
# 58  UIDJS004c0eb4154       2024-09-26               VIP                  Free
# 59  UIDJS004d1ca89e3       2024-08-31               VIP                  Free
# 74  UIDJS005f238dbb0       2024-08-03           Premium                  Free
# 76  UIDJS006315e24bf       2024-03-04              Free               Premium
# 77  UIDJS0063b1fe9a3       2024-07-25               VIP                  Free
# 81  UIDJS006711c9331       2024-06-22              Free                   VIP

# %%
rank ={"Free":1, "Premium":2, "VIP":3}

def cus_plan_change(old_plan, new_plan):

    if rank[new_plan] > rank[old_plan]:
        return "Upgrade"

    elif rank[new_plan] < rank[old_plan]:
        return "Downgrade"
    
    else:
        return "No change"
plan_changed_cus['cus_plan_changed']=plan_changed_cus.apply(lambda rows: cus_plan_change(rows['subscription_plan'], rows['new_subscription_plan']),axis=1)

# %%
plan_changed_cus['subscription_plan'].unique()
# Out:
# array(['Premium', 'VIP', 'Free'], dtype=object)

# %%
plan_changed_cus
# Out:
#                 user_id plan_change_date subscription_plan  \
# 12     UIDJS000cd6a7fe8       2024-12-18           Premium
# 19     UIDJS0019b04b32f       2024-08-11               VIP
# 23     UIDJS001defd7e03       2024-08-18               VIP
# 47     UIDJS003cb5a2cd7       2024-10-05               VIP
# 58     UIDJS004c0eb4154       2024-09-26               VIP
# ...                 ...              ...               ...
# 44598  UIDJSffd997ae360       2024-08-28               VIP
# 44600  UIDJSffdbd91a9cb       2024-08-11               VIP
# 44601  UIDJSffdd37f5584       2024-08-04           Premium
# 44602  UIDJSffe11ff87fb       2024-05-16               VIP
# 44613  UIDJSfff4a6261d2       2024-05-22               VIP
#
#       new_subscription_plan cus_plan_changed
# 12                      VIP          Upgrade
# 19                     Free        Downgrade
# 23                     Free        Downgrade
# 47                     Free        Downgrade
# 58                     Free        Downgrade
# ...                     ...              ...
# 44598                  Free        Downgrade
# 44600               Premium        Downgrade
# 44601                   VIP          Upgrade
# 44602                  Free        Downgrade
# 44613                  Free        Downgrade
#
# [7090 rows x 5 columns]

# %%
plan_changed_cus_grp= plan_changed_cus.groupby('plan_change_date').value_counts(['cus_plan_changed']).to_frame('count').reset_index()

# %%
plan_changed_cus_grp.head()
# Out:
#   plan_change_date cus_plan_changed  count
# 0       2024-02-01        Downgrade      7
# 1       2024-02-02        Downgrade      7
# 2       2024-02-02          Upgrade      3
# 3       2024-02-03          Upgrade      6
# 4       2024-02-03        Downgrade      5

# %%
fig, ax=plt.subplots(figsize=(18,4))
sns.barplot(data=plan_changed_cus_grp.head(100), x='plan_change_date', y='count' , hue='cus_plan_changed')
plt.title('Subscription Trend Over Time')
plt.xlabel('subscription_data')
plt.ylabel('Number of Users')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#  Instendof looking into day wise --> quater wise or monthly wise
plan_changed_cus_grp["plan_change_month"] = plan_changed_cus_grp['plan_change_date'].dt.strftime(date_format="%Y-%m")

# %%
plan_changed_cus_mnt_df = plan_changed_cus_grp.groupby(['plan_change_month','cus_plan_changed'])['count'].sum().to_frame().reset_index()

# %%
plan_changed_cus_mnt_df
# Out:
#    plan_change_month cus_plan_changed  count
# 0            2024-02        Downgrade    193
# 1            2024-02          Upgrade     83
# 2            2024-03        Downgrade    322
# 3            2024-03          Upgrade    149
# 4            2024-04        Downgrade    380
# 5            2024-04          Upgrade    157
# 6            2024-05        Downgrade    416
# 7            2024-05          Upgrade    180
# 8            2024-06        Downgrade    437
# 9            2024-06          Upgrade    178
# 10           2024-07        Downgrade    476
# 11           2024-07          Upgrade    185
# 12           2024-08        Downgrade    556
# 13           2024-08          Upgrade    194
# 14           2024-09        Downgrade    445
# 15           2024-09          Upgrade    186
# 16           2024-10        Downgrade    505
# 17           2024-10          Upgrade    176
# 18           2024-11        Downgrade    695
# 19           2024-11          Upgrade    221
# 20           2024-12        Downgrade    770
# 21           2024-12          Upgrade    186

# %%
fig, ax= plt.subplots(figsize=(15,4))
sns.barplot(data=plan_changed_cus_mnt_df, x='plan_change_month', y ='count', hue='cus_plan_changed')
plt.title('Subscription Trend Over  Time ')
plt.xlabel('Subscription_Data')
plt.ylabel('Number of Users')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Assignment :
# ##### 1.Content Consumption Behavior: Patterns in total watch time, device preferences, and variations by user demographics.
# #### 2.what cause downgrade -Hint: combine content_consumption_df and subscribers_df

# %%
Subscribers_df.head()
# Out:
#             user_id age_group city_tier subscription_date subscription_plan  \
# 0  UIDJS0000751588f     18-24    Tier 1        2024-06-10           Premium
# 1  UIDJS000093eeb86     18-24    Tier 1        2024-11-09              Free
# 2  UIDJS00010d7fa1e     25-34    Tier 1        2024-08-08              Free
# 3  UIDJS00013411a85     35-44    Tier 2        2024-05-31               VIP
# 4  UIDJS0003a3f54cf     35-44    Tier 1        2024-09-20           Premium
#
#   last_active_date plan_change_date new_subscription_plan
# 0              NaT              NaT                   NaN
# 1              NaT              NaT                   NaN
# 2              NaT              NaT                   NaN
# 3              NaT              NaT                   NaN
# 4              NaT              NaT                   NaN

# %%
Subscribers_df['Customer_activity']= Subscribers_df['last_active_date'].fillna('inactivity')

# %%
Subscribers_df['last_active_date'].value_counts()
Subscribers_df['last_active_date'].max()
# Out:
# Timestamp('2024-12-29 00:00:00')

# %%
threushould_date =Subscribers_df['last_active_date'].max() -pd.Timedelta(days=60)     
threushould_date
# Out:
# Timestamp('2024-10-30 00:00:00')

# %%
# checking wheather the customer is inactive from past 60 days.
Subscribers_df['is_inactive'] = Subscribers_df['last_active_date'].isna() | (Subscribers_df['last_active_date'] < threushould_date)

# %%
Subscribers_df
# Out:
#                 user_id age_group city_tier subscription_date  \
# 0      UIDJS0000751588f     18-24    Tier 1        2024-06-10
# 1      UIDJS000093eeb86     18-24    Tier 1        2024-11-09
# 2      UIDJS00010d7fa1e     25-34    Tier 1        2024-08-08
# 3      UIDJS00013411a85     35-44    Tier 2        2024-05-31
# 4      UIDJS0003a3f54cf     35-44    Tier 1        2024-09-20
# ...                 ...       ...       ...               ...
# 44615  UIDJSfffbb38249e     25-34    Tier 2        2024-11-12
# 44616  UIDJSfffbd759005       45+    Tier 1        2024-05-21
# 44617  UIDJSfffebd3002b     25-34    Tier 1        2024-09-27
# 44618  UIDJSffff6698084     35-44    Tier 3        2024-10-12
# 44619  UIDJSffffe298c56     25-34    Tier 2        2024-09-10
#
#       subscription_plan last_active_date plan_change_date  \
# 0               Premium              NaT              NaT
# 1                  Free              NaT              NaT
# 2                  Free              NaT              NaT
# 3                   VIP              NaT              NaT
# 4               Premium              NaT              NaT
# ...                 ...              ...              ...
# 44615              Free              NaT              NaT
# 44616               VIP              NaT              NaT
# 44617               VIP       2024-10-29              NaT
# 44618               VIP              NaT              NaT
# 44619              Free              NaT              NaT
#
#       new_subscription_plan    Customer_activity  is_inactive
# 0                       NaN           inactivity         True
# 1                       NaN           inactivity         True
# 2                       NaN           inactivity         True
# 3                       NaN           inactivity         True
# 4                       NaN           inactivity         True
# ...                     ...                  ...          ...
# 44615                   NaN           inactivity         True
# 44616                   NaN           inactivity         True
# 44617                   NaN  2024-10-29 00:00:00         True
# 44618                   NaN           inactivity         True
# 44619                   NaN           inactivity         True
#
# [44620 rows x 10 columns]

# %%
Subscribers_df[Subscribers_df['is_inactive']][['age_group','is_inactive']].value_counts()
# Out:
# age_group  is_inactive
# 25-34      True           18928
# 35-44      True           10707
# 18-24      True            7208
# 45+        True            5313
# Name: count, dtype: int64

# %%
Subscribers_df[Subscribers_df['is_inactive']== True][['age_group','is_inactive']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='age_group,is_inactive'>

# %%
Subscribers_df[Subscribers_df['is_inactive']==True][['age_group','city_tier']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='age_group,city_tier'>

# %%
sns.countplot(data=Subscribers_df[Subscribers_df['is_inactive'] == True],x= 'age_group', hue='city_tier')
# Out:
# <Axes: xlabel='age_group', ylabel='count'>

# %%
Subscribers_df[Subscribers_df['is_inactive'] == True][['subscription_plan']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='subscription_plan'>
